# %% [markdown]
# # Decision uncertainty
# Illustrative Monte Carlo propagation with sigma=0.05.

# %%
from rdfr_ci.uncertainty import simulate_state_distribution
from rdfr_ci.risk import DEFAULT_WEIGHTS
simulate_state_distribution({'E':.55,'D':.35,'A':.30,'F':.25,'C':.90},DEFAULT_WEIGHTS,n=10000,seed=42)
