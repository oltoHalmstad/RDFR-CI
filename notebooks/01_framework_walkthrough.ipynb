# %% [markdown]
# # RDFR-CI framework walkthrough

# %%
from rdfr_ci.risk import composite_risk, DEFAULT_WEIGHTS
from rdfr_ci.authority import authority_from_score, label
score=composite_risk(.30,.10,.08,.08,.25,DEFAULT_WEIGHTS)
score, label(authority_from_score(score))
