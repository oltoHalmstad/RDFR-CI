# %% [markdown]
# # Cross-sector showcases
# Load the versioned scenario catalog and inspect the six manuscript showcase configurations.

# %%
from pathlib import Path
from rdfr_ci.scenario_loader import load_catalog
sc=load_catalog(Path('..')/'scenarios'/'scenario_catalog.yaml')
[(s.scenario_id,s.title,s.values()) for s in sc[:6]]
