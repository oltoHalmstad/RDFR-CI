# %% [markdown]
# # Detection thresholds
# The authoritative reproducibility path is the script `experiments/run_detection_threshold_demo.py`.

# %%
import pandas as pd
pd.read_csv('../results/tables/table_S5_synthetic_detection_operating_points.csv')
