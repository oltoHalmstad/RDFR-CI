# %% [markdown]
# # Authority ceiling
# The best achievable score at consequence C is R_min = w_C*C.

# %%
from rdfr_ci.authority import authority_ceiling,label
[(c,authority_ceiling(c,.25)[0],label(authority_ceiling(c,.25)[1])) for c in [.25,.5,.75,.8,.9,.95]]
