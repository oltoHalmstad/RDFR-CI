# %% [markdown]
# # SWaT external validation
# This notebook never includes SWaT raw data. Obtain authorized official files separately and use the script runner.

# %%
from pathlib import Path
Path('../data/private/swat').exists()

# %% [markdown]
# Run from the repository root only after authorized access:
#
# `python experiments/swat/run_swat_experiment.py --data-dir data/private/swat`
